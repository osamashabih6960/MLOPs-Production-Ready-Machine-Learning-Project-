# %%
print("OK")
# Out:
# OK

# %%
import pandas as pd

# %%
df = pd.read_csv("Visadataset.csv")
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
df.shape
# Out:
# (25480, 12)

# %%
df.columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
data = df.to_dict(orient="records")
data
# Out:
# [{'case_id': 'EZYV01',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 14513,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 592.2029,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV02',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2412,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 83425.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV03',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 44444,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
#   'prevailing_wage': 122996.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV04',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 98,
#   'yr_of_estab': 1897,
#   'region_of_employment': 'West',
#   'prevailing_wage': 83434.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV05',
#   'continent': 'Africa',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1082,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 149907.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV06',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2339,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'South',
#   'prevailing_wage': 78252.14,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV07',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4985,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'South',
#   'prevailing_wage': 53635.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV08',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3035,
#   'yr_of_estab': 1924,
#   'region_of_employment': 'West',
#   'prevailing_wage': 418.2298,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV09',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4810,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 74362.19,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV10',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2251,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'South',
#   'prevailing_wage': 67514.76,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV11',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2465,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 83588.56,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV12',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4069,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 70813.09,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV13',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 123876,
#   'yr_of_estab': 1963,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 28663.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV14',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1652,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 107196.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV15',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 15756,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'South',
#   'prevailing_wage': 220081.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV16',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4897,
#   'yr_of_estab': 1987,
#   'region_of_employment': 'West',
#   'prevailing_wage': 74108.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV17',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 76638,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 3706.79,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV18',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2747,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'West',
#   'prevailing_wage': 16132.61,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV19',
#   'continent': 'Africa',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4743,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 150441.13,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV20',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 843,
#   'yr_of_estab': 1972,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 79948.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV21',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 880,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
#   'prevailing_wage': 71128.98,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV22',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1706,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 137694.98,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV23',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2878,
#   'yr_of_estab': 1968,
#   'region_of_employment': 'West',
#   'prevailing_wage': 45642.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV24',
#   'continent': 'North America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1517,
#   'yr_of_estab': 1884,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 90108.38,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV25',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 241,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 71286.04,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV26',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1100,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 99489.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV27',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 756,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'South',
#   'prevailing_wage': 86332.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV28',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2889,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 103029.33,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV29',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 18,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 40925.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV30',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 758,
#   'yr_of_estab': 2009,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 189190.48,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV31',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1408,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 79594.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV32',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 995,
#   'yr_of_estab': 1880,
#   'region_of_employment': 'South',
#   'prevailing_wage': 135866.13,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV33',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2415,
#   'yr_of_estab': 1963,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 72077.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV34',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2395,
#   'yr_of_estab': 2000,
#   'region_of_employment': 'South',
#   'prevailing_wage': 81921.18,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV35',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1809,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'South',
#   'prevailing_wage': 225569.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV36',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5512,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 92421.92,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV37',
#   'continent': 'Europe',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2520,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'West',
#   'prevailing_wage': 2490.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV38',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 44,
#   'yr_of_estab': 1965,
#   'region_of_employment': 'South',
#   'prevailing_wage': 110817.26,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV39',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2206,
#   'yr_of_estab': 1909,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 50960.01,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV40',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3729,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 125336.9,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV41',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3723,
#   'yr_of_estab': 2011,
#   'region_of_employment': 'West',
#   'prevailing_wage': 39633.32,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV42',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1209,
#   'yr_of_estab': 1989,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 156326.33,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV43',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 19770,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'West',
#   'prevailing_wage': 43630.58,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV44',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2582,
#   'yr_of_estab': 1989,
#   'region_of_employment': 'South',
#   'prevailing_wage': 54614.42,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV45',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5407,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'West',
#   'prevailing_wage': 28989.87,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV46',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2092,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'South',
#   'prevailing_wage': 22924.91,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV47',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2623,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'South',
#   'prevailing_wage': 61567.75,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV48',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 226,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 156251.17,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV49',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2405,
#   'yr_of_estab': 1933,
#   'region_of_employment': 'South',
#   'prevailing_wage': 86022.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV50',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2171,
#   'yr_of_estab': 1960,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 49565.37,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV51',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 746,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 66191.41,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV52',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3129,
#   'yr_of_estab': 2003,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 95623.2,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV53',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1647,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 115014.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV54',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2438,
#   'yr_of_estab': 1976,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 35018.04,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV55',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 11733,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 230.8072,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV56',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2368,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 113799.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV57',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 779,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'West',
#   'prevailing_wage': 85854.09,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV58',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2825,
#   'yr_of_estab': 1996,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 14174.04,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV59',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3510,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 47176.84,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV60',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2624,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 4949.28,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV61',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 5340,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'West',
#   'prevailing_wage': 67410.59,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV62',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2311,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 58791.58,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV63',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 5110,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'West',
#   'prevailing_wage': 103.2216,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV64',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1316,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'South',
#   'prevailing_wage': 62591.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV65',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 100,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 102919.59,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV66',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2021,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 123468.56,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV67',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 80,
#   'yr_of_estab': 1968,
#   'region_of_employment': 'West',
#   'prevailing_wage': 82324.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV68',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2070,
#   'yr_of_estab': 1847,
#   'region_of_employment': 'West',
#   'prevailing_wage': 5319.49,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV69',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2654,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 153019.94,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV70',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 292,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 38059.89,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV71',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1320,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 230.327,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV72',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1722,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'South',
#   'prevailing_wage': 61521.92,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV73',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3339,
#   'yr_of_estab': 1935,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 121316.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV74',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 452,
#   'yr_of_estab': 1890,
#   'region_of_employment': 'South',
#   'prevailing_wage': 122540.55,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV75',
#   'continent': 'Africa',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3705,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 47170.76,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV76',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 85,
#   'yr_of_estab': 1999,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 330.3743,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV77',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2423,
#   'yr_of_estab': 1838,
#   'region_of_employment': 'West',
#   'prevailing_wage': 2927.34,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV78',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1274,
#   'yr_of_estab': 1999,
#   'region_of_employment': 'South',
#   'prevailing_wage': 107781.48,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV79',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1549,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 590.0203,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV80',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 1062,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'West',
#   'prevailing_wage': 194176.83,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV81',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 32619,
#   'yr_of_estab': 1947,
#   'region_of_employment': 'South',
#   'prevailing_wage': 102073.81,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV82',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4036,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 113882.38,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV83',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 39,
#   'yr_of_estab': 2000,
#   'region_of_employment': 'West',
#   'prevailing_wage': 70778.82,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV84',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2359,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 84125.48,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV85',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 1023,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'South',
#   'prevailing_wage': 174014.59,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV86',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2480,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 34213.17,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV87',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1255,
#   'yr_of_estab': 1989,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 79813.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV88',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4455,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'West',
#   'prevailing_wage': 113327.34,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV89',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2543,
#   'yr_of_estab': 1939,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 78893.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV90',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1359,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'West',
#   'prevailing_wage': 140290.16,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV91',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2324,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 111926.01,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV92',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4103,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 125880.21,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV93',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3667,
#   'yr_of_estab': 1970,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 527.8901,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV94',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 488,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 49357.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV95',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2724,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'South',
#   'prevailing_wage': 69335.2,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV96',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1392,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'South',
#   'prevailing_wage': 99737.18,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV97',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2573,
#   'yr_of_estab': 1977,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 91449.62,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV98',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3524,
#   'yr_of_estab': 1982,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 34494.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV99',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1847,
#   'yr_of_estab': 1977,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 395.995,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV100',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 107535,
#   'yr_of_estab': 1970,
#   'region_of_employment': 'West',
#   'prevailing_wage': 159645.51,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV101',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2227,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 28243.79,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV102',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 334,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 43421.88,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV103',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 224,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 80253.78,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV104',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 367,
#   'yr_of_estab': 1982,
#   'region_of_employment': 'West',
#   'prevailing_wage': 115235.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV105',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 306,
#   'yr_of_estab': 2003,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 95200.86,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV106',
#   'continent': 'North America',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2317,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'Island',
#   'prevailing_wage': 41613.52,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV107',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 890,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'West',
#   'prevailing_wage': 64137.41,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV108',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2002,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'South',
#   'prevailing_wage': 66295.43,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV109',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2903,
#   'yr_of_estab': 1943,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 97520.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV110',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2504,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'West',
#   'prevailing_wage': 65164.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV111',
#   'continent': 'North America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 951,
#   'yr_of_estab': 1956,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 73957.17,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV112',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1327,
#   'yr_of_estab': 1864,
#   'region_of_employment': 'West',
#   'prevailing_wage': 71415.43,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV113',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2421,
#   'yr_of_estab': 1974,
#   'region_of_employment': 'South',
#   'prevailing_wage': 87336.53,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV114',
#   'continent': 'North America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1019,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'South',
#   'prevailing_wage': 98966.72,
#   'unit_of_wage': 'Week',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV115',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1048,
#   'yr_of_estab': 1985,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 83503.6,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV116',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3323,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 57590.66,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV117',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 509,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'South',
#   'prevailing_wage': 32400.2,
#   'unit_of_wage': 'Week',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV118',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2225,
#   'yr_of_estab': 1976,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 65993.21,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV119',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1641,
#   'yr_of_estab': 1984,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 32161.6,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV120',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1144,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 16421.37,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV121',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2334,
#   'yr_of_estab': 1971,
#   'region_of_employment': 'South',
#   'prevailing_wage': 160676.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV122',
#   'continent': 'South America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1415,
#   'yr_of_estab': 1913,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 53114.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV123',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2754,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'South',
#   'prevailing_wage': 19176.21,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV124',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1099,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'West',
#   'prevailing_wage': 204832.52,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV125',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 960,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 40256.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV126',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2750,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'West',
#   'prevailing_wage': 38841.44,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV127',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2753,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 133052.84,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV128',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 23287,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'South',
#   'prevailing_wage': 75234.64,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV129',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2140,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'South',
#   'prevailing_wage': 37032.83,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV130',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 4499,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 61617.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV131',
#   'continent': 'South America',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2554,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 247393.01,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV132',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1333,
#   'yr_of_estab': 1969,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 341.0229,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV133',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 928,
#   'yr_of_estab': 1818,
#   'region_of_employment': 'South',
#   'prevailing_wage': 30570.95,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV134',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4289,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 19477.1,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV135',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 113282,
#   'yr_of_estab': 2011,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 164893.0,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV136',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1948,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'South',
#   'prevailing_wage': 131584.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV137',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
# ...
#   'prevailing_wage': 74635.08,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV956',
#   'continent': 'Oceania',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 17541,
#   'yr_of_estab': 1986,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 75224.53,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV957',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 581,
#   'yr_of_estab': 2014,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 74877.39,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV958',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 573,
#   'yr_of_estab': 2009,
#   'region_of_employment': 'South',
#   'prevailing_wage': 62891.29,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV959',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 12692,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 115239.79,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV960',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 5801,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 99037.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV961',
#   'continent': 'Oceania',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 363,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 97469.69,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV962',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 815,
#   'yr_of_estab': 1993,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 69825.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV963',
#   'continent': 'Europe',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3944,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 276.7576,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV964',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1606,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 3435.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV965',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3323,
#   'yr_of_estab': 2007,
#   'region_of_employment': 'West',
#   'prevailing_wage': 32421.05,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV966',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 898,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 122187.35,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV967',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2619,
#   'yr_of_estab': 1981,
#   'region_of_employment': 'West',
#   'prevailing_wage': 62376.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV968',
#   'continent': 'Europe',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 4035,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 41360.5,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV969',
#   'continent': 'Africa',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5707,
#   'yr_of_estab': 2002,
#   'region_of_employment': 'West',
#   'prevailing_wage': 103813.15,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV970',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2803,
#   'yr_of_estab': 2004,
#   'region_of_employment': 'South',
#   'prevailing_wage': 139924.14,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV971',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 142,
#   'yr_of_estab': 1998,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 32341.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV972',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 5963,
#   'yr_of_estab': 2009,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 26217.34,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV973',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3336,
#   'yr_of_estab': 1994,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 65227.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV974',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4589,
#   'yr_of_estab': 1985,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 81132.15,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV975',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 2681,
#   'yr_of_estab': 2008,
#   'region_of_employment': 'South',
#   'prevailing_wage': 79079.87,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV976',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 5601,
#   'yr_of_estab': 2014,
#   'region_of_employment': 'South',
#   'prevailing_wage': 132150.73,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV977',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 499,
#   'yr_of_estab': 1984,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 98867.47,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV978',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 3716,
#   'yr_of_estab': 1999,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 311.1659,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV979',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 866,
#   'yr_of_estab': 2012,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 41439.87,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV980',
#   'continent': 'Asia',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 394921,
#   'yr_of_estab': 1975,
#   'region_of_employment': 'South',
#   'prevailing_wage': 106460.43,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV981',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2444,
#   'yr_of_estab': 2006,
#   'region_of_employment': 'West',
#   'prevailing_wage': 30497.97,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV982',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3107,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 89256.68,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV983',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2824,
#   'yr_of_estab': 2010,
#   'region_of_employment': 'West',
#   'prevailing_wage': 95016.97,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV984',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 1836,
#   'yr_of_estab': 1975,
#   'region_of_employment': 'West',
#   'prevailing_wage': 16780.57,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV985',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 63,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 78553.09,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV986',
#   'continent': 'Europe',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2097,
#   'yr_of_estab': 1914,
#   'region_of_employment': 'Midwest',
#   'prevailing_wage': 125702.65,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV987',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 444,
#   'yr_of_estab': 2013,
#   'region_of_employment': 'West',
#   'prevailing_wage': 29951.72,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV988',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 3329,
#   'yr_of_estab': 1983,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 144548.82,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV989',
#   'continent': 'North America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 6070,
#   'yr_of_estab': 1997,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 50956.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV990',
#   'continent': 'Europe',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 860,
#   'yr_of_estab': 1988,
#   'region_of_employment': 'South',
#   'prevailing_wage': 70892.12,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV991',
#   'continent': 'North America',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 13728,
#   'yr_of_estab': 1968,
#   'region_of_employment': 'South',
#   'prevailing_wage': 72626.0,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV992',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2749,
#   'yr_of_estab': 1996,
#   'region_of_employment': 'South',
#   'prevailing_wage': 39114.03,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV993',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'Y',
#   'no_of_employees': 2595,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 142300.54,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV994',
#   'continent': 'South America',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 1228,
#   'yr_of_estab': 1995,
#   'region_of_employment': 'Northeast',
#   'prevailing_wage': 314.2371,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV995',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 273,
#   'yr_of_estab': 2001,
#   'region_of_employment': 'West',
#   'prevailing_wage': 56495.99,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV996',
#   'continent': 'Asia',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 302,
#   'yr_of_estab': 2000,
#   'region_of_employment': 'South',
#   'prevailing_wage': 47.4872,
#   'unit_of_wage': 'Hour',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV997',
#   'continent': 'North America',
#   'education_of_employee': "Master's",
#   'has_job_experience': 'N',
#   'requires_job_training': 'N',
#   'no_of_employees': 2294,
#   'yr_of_estab': 2005,
#   'region_of_employment': 'West',
#   'prevailing_wage': 109711.81,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'N',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV998',
#   'continent': 'Asia',
#   'education_of_employee': "Bachelor's",
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 4266,
#   'yr_of_estab': 1976,
#   'region_of_employment': 'South',
#   'prevailing_wage': 208952.02,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  {'case_id': 'EZYV999',
#   'continent': 'Asia',
#   'education_of_employee': 'High School',
#   'has_job_experience': 'Y',
#   'requires_job_training': 'N',
#   'no_of_employees': 21013,
#   'yr_of_estab': 1991,
#   'region_of_employment': 'West',
#   'prevailing_wage': 88780.76,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Denied'},
#  {'case_id': 'EZYV1000',
#   'continent': 'Europe',
#   'education_of_employee': 'Doctorate',
#   'has_job_experience': 'N',
#   'requires_job_training': 'Y',
#   'no_of_employees': 115,
#   'yr_of_estab': 1965,
#   'region_of_employment': 'South',
#   'prevailing_wage': 48947.85,
#   'unit_of_wage': 'Year',
#   'full_time_position': 'Y',
#   'case_status': 'Certified'},
#  ...]

# %%
len(data)
# Out:
# 25480

# %%
DB_NAME = "US_VISA"
COLLECTION_NAME = "visa_data"
CONNECTION_URL = "use your url"

# %%
import pymongo

# %%
print(CONNECTION_URL)
# Out:
# use your url

# %%
CONNECTION_URL = "mongodb://localhost:27017/"

# %%
import pymongo

CONNECTION_URL = "mongodb://localhost:27017/"
DB_NAME = "US_VISA"
COLLECTION_NAME = "visa_data"
#CONNECTION_URL = "use your url"

client = pymongo.MongoClient(CONNECTION_URL)
data_base = client[DB_NAME]
collection = data_base[COLLECTION_NAME]

rec = collection.insert_many(data)
print("Inserted IDs:", rec.inserted_ids)
# Out:
# Inserted IDs: [ObjectId('697aec250bcaf783dbcf1e84'), ObjectId('697aec250bcaf783dbcf1e85'), ObjectId('697aec250bcaf783dbcf1e86'), ObjectId('697aec250bcaf783dbcf1e87'), ObjectId('697aec250bcaf783dbcf1e88'), ObjectId('697aec250bcaf783dbcf1e89'), ObjectId('697aec250bcaf783dbcf1e8a'), ObjectId('697aec250bcaf783dbcf1e8b'), ObjectId('697aec250bcaf783dbcf1e8c'), ObjectId('697aec250bcaf783dbcf1e8d'), ObjectId('697aec250bcaf783dbcf1e8e'), ObjectId('697aec250bcaf783dbcf1e8f'), ObjectId('697aec250bcaf783dbcf1e90'), ObjectId('697aec250bcaf783dbcf1e91'), ObjectId('697aec250bcaf783dbcf1e92'), ObjectId('697aec250bcaf783dbcf1e93'), ObjectId('697aec250bcaf783dbcf1e94'), ObjectId('697aec250bcaf783dbcf1e95'), ObjectId('697aec250bcaf783dbcf1e96'), ObjectId('697aec250bcaf783dbcf1e97'), ObjectId('697aec250bcaf783dbcf1e98'), ObjectId('697aec250bcaf783dbcf1e99'), ObjectId('697aec250bcaf783dbcf1e9a'), ObjectId('697aec250bcaf783dbcf1e9b'), ObjectId('697aec250bcaf783dbcf1e9c'), ObjectId('697aec250bcaf783dbcf1e9d'), ObjectId('697aec250bcaf783dbcf1e9e'), ObjectId('697aec250bcaf783dbcf1e9f'), ObjectId('697aec250bcaf783dbcf1ea0'), ObjectId('697aec250bcaf783dbcf1ea1'), ObjectId('697aec250bcaf783dbcf1ea2'), ObjectId('697aec250bcaf783dbcf1ea3'), ObjectId('697aec250bcaf783dbcf1ea4'), ObjectId('697aec250bcaf783dbcf1ea5'), ObjectId('697aec250bcaf783dbcf1ea6'), ObjectId('697aec250bcaf783dbcf1ea7'), ObjectId('697aec250bcaf783dbcf1ea8'), ObjectId('697aec250bcaf783dbcf1ea9'), ObjectId('697aec250bcaf783dbcf1eaa'), ObjectId('697aec250bcaf783dbcf1eab'), ObjectId('697aec250bcaf783dbcf1eac'), ObjectId('697aec250bcaf783dbcf1ead'), ObjectId('697aec250bcaf783dbcf1eae'), ObjectId('697aec250bcaf783dbcf1eaf'), ObjectId('697aec250bcaf783dbcf1eb0'), ObjectId('697aec250bcaf783dbcf1eb1'), ObjectId('697aec250bcaf783dbcf1eb2'), ObjectId('697aec250bcaf783dbcf1eb3'), ObjectId('697aec250bcaf783dbcf1eb4'), ObjectId('697aec250bcaf783dbcf1eb5'), ObjectId('697aec250bcaf783dbcf1eb6'), ObjectId('697aec250bcaf783dbcf1eb7'), ObjectId('697aec250bcaf783dbcf1eb8'), ObjectId('697aec250bcaf783dbcf1eb9'), ObjectId('697aec250bcaf783dbcf1eba'), ObjectId('697aec250bcaf783dbcf1ebb'), ObjectId('697aec250bcaf783dbcf1ebc'), ObjectId('697aec250bcaf783dbcf1ebd'), ObjectId('697aec250bcaf783dbcf1ebe'), ObjectId('697aec250bcaf783dbcf1ebf'), ObjectId('697aec250bcaf783dbcf1ec0'), ObjectId('697aec250bcaf783dbcf1ec1'), ObjectId('697aec250bcaf783dbcf1ec2'), ObjectId('697aec250bcaf783dbcf1ec3'), ObjectId('697aec250bcaf783dbcf1ec4'), ObjectId('697aec250bcaf783dbcf1ec5'), ObjectId('697aec250bcaf783dbcf1ec6'), ObjectId('697aec250bcaf783dbcf1ec7'), ObjectId('697aec250bcaf783dbcf1ec8'), ObjectId('697aec250bcaf783dbcf1ec9'), ObjectId('697aec250bcaf783dbcf1eca'), ObjectId('697aec250bcaf783dbcf1ecb'), ObjectId('697aec250bcaf783dbcf1ecc'), ObjectId('697aec250bcaf783dbcf1ecd'), ObjectId('697aec250bcaf783dbcf1ece'), ObjectId('697aec250bcaf783dbcf1ecf'), ObjectId('697aec250bcaf783dbcf1ed0'), ObjectId('697aec250bcaf783dbcf1ed1'), ObjectId('697aec250bcaf783dbcf1ed2'), ObjectId('697aec250bcaf783dbcf1ed3'), ObjectId('697aec250bcaf783dbcf1ed4'), ObjectId('697aec250bcaf783dbcf1ed5'), ObjectId('697aec250bcaf783dbcf1ed6'), ObjectId('697aec250bcaf783dbcf1ed7'), ObjectId('697aec250bcaf783dbcf1ed8'), ObjectId('697aec250bcaf783dbcf1ed9'), ObjectId('697aec250bcaf783dbcf1eda'), ObjectId('697aec250bcaf783dbcf1edb'), ObjectId('697aec250bcaf783dbcf1edc'), ObjectId('697aec250bcaf783dbcf1edd'), ObjectId('697aec250bcaf783dbcf1ede'), ObjectId('697aec250bcaf783dbcf1edf'), ObjectId('697aec250bcaf783dbcf1ee0'), ObjectId('697aec250bcaf783dbcf1ee1'), ObjectId('697aec250bcaf783dbcf1ee2'), ObjectId('697aec250bcaf783dbcf1ee3'), ObjectId('697aec250bcaf783dbcf1ee4'), ObjectId('697aec250bcaf783dbcf1ee5'), ObjectId('697aec250bcaf783dbcf1ee6'), ObjectId('697aec250bcaf783dbcf1ee7'), ObjectId('697aec250bcaf783dbcf1ee8'), ObjectId('697aec250bcaf783dbcf1ee9'), ObjectId('697aec250bcaf783dbcf1eea'), ObjectId('697aec250bcaf783dbcf1eeb'), ObjectId('697aec250bcaf783dbcf1ee ...

# %%
records = collection.find()
records

# %%
for i, j in enumerate(records):
    print(f"{i}: {j}")
# Out:
# 0: {'_id': ObjectId('697aec250bcaf783dbcf1e84'), 'case_id': 'EZYV01', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 14513, 'yr_of_estab': 2007, 'region_of_employment': 'West', 'prevailing_wage': 592.2029, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 1: {'_id': ObjectId('697aec250bcaf783dbcf1e85'), 'case_id': 'EZYV02', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2412, 'yr_of_estab': 2002, 'region_of_employment': 'Northeast', 'prevailing_wage': 83425.65, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 2: {'_id': ObjectId('697aec250bcaf783dbcf1e86'), 'case_id': 'EZYV03', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 44444, 'yr_of_estab': 2008, 'region_of_employment': 'West', 'prevailing_wage': 122996.86, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 3: {'_id': ObjectId('697aec250bcaf783dbcf1e87'), 'case_id': 'EZYV04', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 98, 'yr_of_estab': 1897, 'region_of_employment': 'West', 'prevailing_wage': 83434.03, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 4: {'_id': ObjectId('697aec250bcaf783dbcf1e88'), 'case_id': 'EZYV05', 'continent': 'Africa', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1082, 'yr_of_estab': 2005, 'region_of_employment': 'South', 'prevailing_wage': 149907.39, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 5: {'_id': ObjectId('697aec250bcaf783dbcf1e89'), 'case_id': 'EZYV06', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2339, 'yr_of_estab': 2012, 'region_of_employment': 'South', 'prevailing_wage': 78252.14, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 6: {'_id': ObjectId('697aec250bcaf783dbcf1e8a'), 'case_id': 'EZYV07', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 4985, 'yr_of_estab': 1994, 'region_of_employment': 'South', 'prevailing_wage': 53635.39, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 7: {'_id': ObjectId('697aec250bcaf783dbcf1e8b'), 'case_id': 'EZYV08', 'continent': 'North America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3035, 'yr_of_estab': 1924, 'region_of_employment': 'West', 'prevailing_wage': 418.2298, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 8: {'_id': ObjectId('697aec250bcaf783dbcf1e8c'), 'case_id': 'EZYV09', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 4810, 'yr_of_estab': 2012, 'region_of_employment': 'Midwest', 'prevailing_wage': 74362.19, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 9: {'_id': ObjectId('697aec250bcaf783dbcf1e8d'), 'case_id': 'EZYV10', 'continent': 'Europe', 'education_of_employee': 'Doctorate', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2251, 'yr_of_estab': 1995, 'region_of_employment': 'South', 'prevailing_wage': 67514.76, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 10: {'_id': ObjectId('697aec250bcaf783dbcf1e8e'), 'case_id': 'EZYV11', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2465, 'yr_of_estab': 2004, 'region_of_employment': 'Midwest', 'prevailing_wage': 83588.56, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 11: {'_id': ObjectId('697aec250bcaf783dbcf1e8f'), 'case_id': 'EZYV12', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4069, 'yr_of_estab': 2005, 'region_of_employment': 'Northeast', 'prevailing_wage': 70813.09, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 12: {'_id': ObjectId('697aec250bcaf783dbcf1e90'), 'case_id': 'EZYV13', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 123876, 'yr_of_estab': 1963, 'region_of_employment': 'Northeast', 'prevailing_wage': 28663.05, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 13: {'_id': ObjectId('697aec250bcaf783dbcf1e91'), 'case_id': 'EZYV14', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1652, 'yr_of_estab': 2007, 'region_of_employment': 'Midwest', 'prevailing_wage': 107196.03, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 14: {'_id': ObjectId('697aec250bcaf783dbcf1e92'), 'case_id': 'EZYV15', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 15756, 'yr_of_estab': 2006, 'region_of_employment': 'South', 'prevailing_wage': 220081.73, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 15: {'_id': ObjectId('697aec250bcaf783dbcf1e93'), 'case_id': 'EZYV16', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4897, 'yr_of_estab': 1987, 'region_of_employment': 'West', 'prevailing_wage': 74108.02, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 16: {'_id': ObjectId('697aec250bcaf783dbcf1e94'), 'case_id': 'EZYV17', 'continent': 'Europe', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 76638, 'yr_of_estab': 1991, 'region_of_employment': 'Midwest', 'prevailing_wage': 3706.79, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 17: {'_id': ObjectId('697aec250bcaf783dbcf1e95'), 'case_id': 'EZYV18', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2747, 'yr_of_estab': 2001, 'region_of_employment': 'West', 'prevailing_wage': 16132.61, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 18: {'_id': ObjectId('697aec250bcaf783dbcf1e96'), 'case_id': 'EZYV19', 'continent': 'Africa', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4743, 'yr_of_estab': 2004, 'region_of_employment': 'Midwest', 'prevailing_wage': 150441.13, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 19: {'_id': ObjectId('697aec250bcaf783dbcf1e97'), 'case_id': 'EZYV20', 'continent': 'Asia', 'education_of_employee': 'Doctorate', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 843, 'yr_of_estab': 1972, 'region_of_employment': 'Midwest', 'prevailing_wage': 79948.12, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 20: {'_id': ObjectId('697aec250bcaf783dbcf1e98'), 'case_id': 'EZYV21', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 880, 'yr_of_estab': 2008, 'region_of_employment': 'West', 'prevailing_wage': 71128.98, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 21: {'_id': ObjectId('697aec250bcaf783dbcf1e99'), 'case_id': 'EZYV22', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1706, 'yr_of_estab': 2013, 'region_of_employment': 'Midwest', 'prevailing_wage': 137694.98, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 22: {'_id': ObjectId('697aec250bcaf783dbcf1e9a'), 'case_id': 'EZYV23', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2878, 'yr_of_estab': 1968, 'region_of_employment': 'West', 'prevailing_wage': 45642.39, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 23: {'_id': ObjectId('697aec250bcaf783dbcf1e9b'), 'case_id': 'EZYV24', 'continent': 'North America', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1517, 'yr_of_estab': 1884, 'region_of_employment': 'Midwest', 'prevailing_wage': 90108.38, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 24: {'_id': ObjectId('697aec250bcaf783dbcf1e9c'), 'case_id': 'EZYV25', 'continent': 'Europe', 'education_of_employee': 'Doctorate', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 241, 'yr_of_estab': 1981, 'region_of_employment': 'Midwest', 'prevailing_wage': 71286.04, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25: {'_id': ObjectId('697aec250bcaf783dbcf1e9d'), 'case_id': 'EZYV26', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1100, 'yr_of_estab': 1997, 'region_of_employment': 'Midwest', 'prevailing_wage': 99489.65, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 26: {'_id': ObjectId('697aec250bcaf783dbcf1e9e'), 'case_id': 'EZYV27', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 756, 'yr_of_estab': 1995, 'region_of_employment': 'South', 'prevailing_wage': 86332.95, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 27: {'_id': ObjectId('697aec250bcaf783dbcf1e9f'), 'case_id': 'EZYV28', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 2889, 'yr_of_estab': 2005, 'region_of_employment': 'South', 'prevailing_wage': 103029.33, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 28: {'_id': ObjectId('697aec250bcaf783dbcf1ea0'), 'case_id': 'EZYV29', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 18, 'yr_of_estab': 2004, 'region_of_employment': 'Northeast', 'prevailing_wage': 40925.86, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 29: {'_id': ObjectId('697aec250bcaf783dbcf1ea1'), 'case_id': 'EZYV30', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 758, 'yr_of_estab': 2009, 'region_of_employment': 'Northeast', 'prevailing_wage': 189190.48, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 30: {'_id': ObjectId('697aec250bcaf783dbcf1ea2'), 'case_id': 'EZYV31', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1408, 'yr_of_estab': 1998, 'region_of_employment': 'Midwest', 'prevailing_wage': 79594.12, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 31: {'_id': ObjectId('697aec250bcaf783dbcf1ea3'), 'case_id': 'EZYV32', 'continent': 'Asia', 'education_of_employee': 'Doctorate', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 995, 'yr_of_estab': 1880, 'region_of_employment': 'South', 'prevailing_wage': 135866.13, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 32: {'_id': ObjectId('697aec250bcaf783dbcf1ea4'), 'case_id': 'EZYV33', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2415, 'yr_of_estab': 1963, 'region_of_employment': 'Midwest', 'prevailing_wage': 72077.57, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 33: {'_id': ObjectId('697aec250bcaf783dbcf1ea5'), 'case_id': 'EZYV34', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2395, 'yr_of_estab': 2000, 'region_of_employment': 'South', 'prevailing_wage': 81921.18, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 34: {'_id': ObjectId('697aec250bcaf783dbcf1ea6'), 'case_id': 'EZYV35', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1809, 'yr_of_estab': 2010, 'region_of_employment': 'South', 'prevailing_wage': 225569.73, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 35: {'_id': ObjectId('697aec250bcaf783dbcf1ea7'), 'case_id': 'EZYV36', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 5512, 'yr_of_estab': 2001, 'region_of_employment': 'Northeast', 'prevailing_wage': 92421.92, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 36: {'_id': ObjectId('697aec250bcaf783dbcf1ea8'), 'case_id': 'EZYV37', 'continent': 'Europe', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2520, 'yr_of_estab': 1981, 'region_of_employment': 'West', 'prevailing_wage': 2490.12, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 37: {'_id': ObjectId('697aec250bcaf783dbcf1ea9'), 'case_id': 'EZYV38', 'continent': 'Europe', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 44, 'yr_of_estab': 1965, 'region_of_employment': 'South', 'prevailing_wage': 110817.26, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 38: {'_id': ObjectId('697aec250bcaf783dbcf1eaa'), 'case_id': 'EZYV39', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 2206, 'yr_of_estab': 1909, 'region_of_employment': 'Northeast', 'prevailing_wage': 50960.01, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 39: {'_id': ObjectId('697aec250bcaf783dbcf1eab'), 'case_id': 'EZYV40', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 3729, 'yr_of_estab': 2007, 'region_of_employment': 'Midwest', 'prevailing_wage': 125336.9, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 40: {'_id': ObjectId('697aec250bcaf783dbcf1eac'), 'case_id': 'EZYV41', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3723, 'yr_of_estab': 2011, 'region_of_employment': 'West', 'prevailing_wage': 39633.32, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 41: {'_id': ObjectId('697aec250bcaf783dbcf1ead'), 'case_id': 'EZYV42', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1209, 'yr_of_estab': 1989, 'region_of_employment': 'Northeast', 'prevailing_wage': 156326.33, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 42: {'_id': ObjectId('697aec250bcaf783dbcf1eae'), 'case_id': 'EZYV43', 'continent': 'Europe', 'education_of_employee': 'Doctorate', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 19770, 'yr_of_estab': 2005, 'region_of_employment': 'West', 'prevailing_wage': 43630.58, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 43: {'_id': ObjectId('697aec250bcaf783dbcf1eaf'), 'case_id': 'EZYV44', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2582, 'yr_of_estab': 1989, 'region_of_employment': 'South', 'prevailing_wage': 54614.42, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 44: {'_id': ObjectId('697aec250bcaf783dbcf1eb0'), 'case_id': 'EZYV45', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 5407, 'yr_of_estab': 1998, 'region_of_employment': 'West', 'prevailing_wage': 28989.87, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 45: {'_id': ObjectId('697aec250bcaf783dbcf1eb1'), 'case_id': 'EZYV46', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 2092, 'yr_of_estab': 1998, 'region_of_employment': 'South', 'prevailing_wage': 22924.91, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 46: {'_id': ObjectId('697aec250bcaf783dbcf1eb2'), 'case_id': 'EZYV47', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2623, 'yr_of_estab': 2008, 'region_of_employment': 'South', 'prevailing_wage': 61567.75, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 47: {'_id': ObjectId('697aec250bcaf783dbcf1eb3'), 'case_id': 'EZYV48', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 226, 'yr_of_estab': 1991, 'region_of_employment': 'Midwest', 'prevailing_wage': 156251.17, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 48: {'_id': ObjectId('697aec250bcaf783dbcf1eb4'), 'case_id': 'EZYV49', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2405, 'yr_of_estab': 1933, 'region_of_employment': 'South', 'prevailing_wage': 86022.02, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 49: {'_id': ObjectId('697aec250bcaf783dbcf1eb5'), 'case_id': 'EZYV50', 'continent': 'Asia', 'education_of_employee': 'Doctorate', 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 2171, 'yr_of_estab': 1960, 'region_of_employment': 'Northeast', 'prevailing_wage': 49565.37, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 50: {'_id': ObjectId('697aec250bcaf783dbcf1eb6'), 'case_id': 'EZYV51', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 746, 'yr_of_estab': 1991, 'region_of_employment': 'Midwest', 'prevailing_wage': 66191.41, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 51: {'_id': ObjectId('697aec250bcaf783dbcf1eb7'), 'case_id': 'EZYV52', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3129, 'yr_of_estab': 2003, 'region_of_employment': 'Midwest', 'prevailing_wage': 95623.2, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 52: {'_id': ObjectId('697aec250bcaf783dbcf1eb8'), 'case_id': 'EZYV53', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1647, 'yr_of_estab': 1998, 'region_of_employment': 'Midwest', 'prevailing_wage': 115014.05, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 53: {'_id': ObjectId('697aec250bcaf783dbcf1eb9'), 'case_id': 'EZYV54', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2438, 'yr_of_estab': 1976, 'region_of_employment': 'Midwest', 'prevailing_wage': 35018.04, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 54: {'_id': ObjectId('697aec250bcaf783dbcf1eba'), 'case_id': 'EZYV55', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 11733, 'yr_of_estab': 1995, 'region_of_employment': 'Northeast', 'prevailing_wage': 230.8072, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 55: {'_id': ObjectId('697aec250bcaf783dbcf1ebb'), 'case_id': 'EZYV56', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2368, 'yr_of_estab': 1998, 'region_of_employment': 'Northeast', 'prevailing_wage': 113799.64, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 56: {'_id': ObjectId('697aec250bcaf783dbcf1ebc'), 'case_id': 'EZYV57', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 779, 'yr_of_estab': 1994, 'region_of_employment': 'West', 'prevailing_wage': 85854.09, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 57: {'_id': ObjectId('697aec250bcaf783dbcf1ebd'), 'case_id': 'EZYV58', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2825, 'yr_of_estab': 1996, 'region_of_employment': 'Northeast', 'prevailing_wage': 14174.04, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 58: {'_id': ObjectId('697aec250bcaf783dbcf1ebe'), 'case_id': 'EZYV59', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 3510, 'yr_of_estab': 2007, 'region_of_employment': 'West', 'prevailing_wage': 47176.84, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 59: {'_id': ObjectId('697aec250bcaf783dbcf1ebf'), 'case_id': 'EZYV60', 'continent': 'Asia', 'education_of_employee': 'Doctorate', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2624, 'yr_of_estab': 2012, 'region_of_employment': 'Midwest', 'prevailing_wage': 4949.28, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 60: {'_id': ObjectId('697aec250bcaf783dbcf1ec0'), 'case_id': 'EZYV61', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 5340, 'yr_of_estab': 2010, 'region_of_employment': 'West', 'prevailing_wage': 67410.59, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 61: {'_id': ObjectId('697aec250bcaf783dbcf1ec1'), 'case_id': 'EZYV62', 'continent': 'Europe', 'education_of_employee': 'Doctorate', 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 2311, 'yr_of_estab': 1994, 'region_of_employment': 'Midwest', 'prevailing_wage': 58791.58, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 62: {'_id': ObjectId('697aec250bcaf783dbcf1ec2'), 'case_id': 'EZYV63', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 5110, 'yr_of_estab': 2004, 'region_of_employment': 'West', 'prevailing_wage': 103.2216, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 63: {'_id': ObjectId('697aec250bcaf783dbcf1ec3'), 'case_id': 'EZYV64', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1316, 'yr_of_estab': 1995, 'region_of_employment': 'South', 'prevailing_wage': 62591.57, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 64: {'_id': ObjectId('697aec250bcaf783dbcf1ec4'), 'case_id': 'EZYV65', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 100, 'yr_of_estab': 2001, 'region_of_employment': 'Northeast', 'prevailing_wage': 102919.59, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 65: {'_id': ObjectId('697aec250bcaf783dbcf1ec5'), 'case_id': 'EZYV66', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2021, 'yr_of_estab': 2007, 'region_of_employment': 'Midwest', 'prevailing_wage': 123468.56, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 66: {'_id': ObjectId('697aec250bcaf783dbcf1ec6'), 'case_id': 'EZYV67', 'continent': 'North America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 80, 'yr_of_estab': 1968, 'region_of_employment': 'West', 'prevailing_wage': 82324.64, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Denied'}
# 67: {'_id': ObjectId('697aec250bcaf783dbcf1ec7'), 'case_id': 'EZYV68', 'continent': 'Europe', 'education_of_employee': 'Doctorate', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2070, 'yr_of_estab': 1847, 'region_of_employment': 'West', 'prevailing_wage': 5319.49, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 68: {'_id': ObjectId('697aec250bcaf783dbcf1ec8'), 'case_id': 'EZYV69', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 2654, 'yr_of_estab': 2013, 'region_of_employment': 'Midwest', 'prevailing_wage': 153019.94, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 69: {'_id': ObjectId('697aec250bcaf783dbcf1ec9'), 'case_id': 'EZYV70', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 292, 'yr_of_estab': 2005, 'region_of_employment': 'South', 'prevailing_wage': 38059.89, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 70: {'_id': ObjectId('697aec250bcaf783dbcf1eca'), 'case_id': 'EZYV71', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1320, 'yr_of_estab': 2001, 'region_of_employment': 'Northeast', 'prevailing_wage': 230.327, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 71: {'_id': ObjectId('697aec250bcaf783dbcf1ecb'), 'case_id': 'EZYV72', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1722, 'yr_of_estab': 2007, 'region_of_employment': 'South', 'prevailing_wage': 61521.92, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 72: {'_id': ObjectId('697aec250bcaf783dbcf1ecc'), 'case_id': 'EZYV73', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3339, 'yr_of_estab': 1935, 'region_of_employment': 'Northeast', 'prevailing_wage': 121316.5, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 73: {'_id': ObjectId('697aec250bcaf783dbcf1ecd'), 'case_id': 'EZYV74', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 452, 'yr_of_estab': 1890, 'region_of_employment': 'South', 'prevailing_wage': 122540.55, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 74: {'_id': ObjectId('697aec250bcaf783dbcf1ece'), 'case_id': 'EZYV75', 'continent': 'Africa', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3705, 'yr_of_estab': 2001, 'region_of_employment': 'South', 'prevailing_wage': 47170.76, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 75: {'_id': ObjectId('697aec250bcaf783dbcf1ecf'), 'case_id': 'EZYV76', 'continent': 'North America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 85, 'yr_of_estab': 1999, 'region_of_employment': 'Northeast', 'prevailing_wage': 330.3743, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 76: {'_id': ObjectId('697aec250bcaf783dbcf1ed0'), 'case_id': 'EZYV77', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2423, 'yr_of_estab': 1838, 'region_of_employment': 'West', 'prevailing_wage': 2927.34, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 77: {'_id': ObjectId('697aec250bcaf783dbcf1ed1'), 'case_id': 'EZYV78', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1274, 'yr_of_estab': 1999, 'region_of_employment': 'South', 'prevailing_wage': 107781.48, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 78: {'_id': ObjectId('697aec250bcaf783dbcf1ed2'), 'case_id': 'EZYV79', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1549, 'yr_of_estab': 2001, 'region_of_employment': 'South', 'prevailing_wage': 590.0203, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 79: {'_id': ObjectId('697aec250bcaf783dbcf1ed3'), 'case_id': 'EZYV80', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 1062, 'yr_of_estab': 1998, 'region_of_employment': 'West', 'prevailing_wage': 194176.83, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 80: {'_id': ObjectId('697aec250bcaf783dbcf1ed4'), 'case_id': 'EZYV81', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 32619, 'yr_of_estab': 1947, 'region_of_employment': 'South', 'prevailing_wage': 102073.81, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 81: {'_id': ObjectId('697aec250bcaf783dbcf1ed5'), 'case_id': 'EZYV82', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4036, 'yr_of_estab': 2001, 'region_of_employment': 'South', 'prevailing_wage': 113882.38, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 82: {'_id': ObjectId('697aec250bcaf783dbcf1ed6'), 'case_id': 'EZYV83', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 39, 'yr_of_estab': 2000, 'region_of_employment': 'West', 'prevailing_wage': 70778.82, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 83: {'_id': ObjectId('697aec250bcaf783dbcf1ed7'), 'case_id': 'EZYV84', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2359, 'yr_of_estab': 2007, 'region_of_employment': 'Northeast', 'prevailing_wage': 84125.48, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 84: {'_id': ObjectId('697aec250bcaf783dbcf1ed8'), 'case_id': 'EZYV85', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 1023, 'yr_of_estab': 2002, 'region_of_employment': 'South', 'prevailing_wage': 174014.59, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 85: {'_id': ObjectId('697aec250bcaf783dbcf1ed9'), 'case_id': 'EZYV86', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2480, 'yr_of_estab': 1981, 'region_of_employment': 'Northeast', 'prevailing_wage': 34213.17, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 86: {'_id': ObjectId('697aec250bcaf783dbcf1eda'), 'case_id': 'EZYV87', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1255, 'yr_of_estab': 1989, 'region_of_employment': 'Northeast', 'prevailing_wage': 79813.05, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Denied'}
# 87: {'_id': ObjectId('697aec250bcaf783dbcf1edb'), 'case_id': 'EZYV88', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4455, 'yr_of_estab': 1998, 'region_of_employment': 'West', 'prevailing_wage': 113327.34, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 88: {'_id': ObjectId('697aec250bcaf783dbcf1edc'), 'case_id': 'EZYV89', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2543, 'yr_of_estab': 1939, 'region_of_employment': 'Northeast', 'prevailing_wage': 78893.64, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 89: {'_id': ObjectId('697aec250bcaf783dbcf1edd'), 'case_id': 'EZYV90', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1359, 'yr_of_estab': 2008, 'region_of_employment': 'West', 'prevailing_wage': 140290.16, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 90: {'_id': ObjectId('697aec250bcaf783dbcf1ede'), 'case_id': 'EZYV91', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 2324, 'yr_of_estab': 2006, 'region_of_employment': 'Northeast', 'prevailing_wage': 111926.01, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 91: {'_id': ObjectId('697aec250bcaf783dbcf1edf'), 'case_id': 'EZYV92', 'continent': 'North America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 4103, 'yr_of_estab': 2004, 'region_of_employment': 'Northeast', 'prevailing_wage': 125880.21, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 92: {'_id': ObjectId('697aec250bcaf783dbcf1ee0'), 'case_id': 'EZYV93', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 3667, 'yr_of_estab': 1970, 'region_of_employment': 'Northeast', 'prevailing_wage': 527.8901, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 93: {'_id': ObjectId('697aec250bcaf783dbcf1ee1'), 'case_id': 'EZYV94', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 488, 'yr_of_estab': 2010, 'region_of_employment': 'Midwest', 'prevailing_wage': 49357.95, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 94: {'_id': ObjectId('697aec250bcaf783dbcf1ee2'), 'case_id': 'EZYV95', 'continent': 'North America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2724, 'yr_of_estab': 1998, 'region_of_employment': 'South', 'prevailing_wage': 69335.2, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 95: {'_id': ObjectId('697aec250bcaf783dbcf1ee3'), 'case_id': 'EZYV96', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1392, 'yr_of_estab': 2001, 'region_of_employment': 'South', 'prevailing_wage': 99737.18, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 96: {'_id': ObjectId('697aec250bcaf783dbcf1ee4'), 'case_id': 'EZYV97', 'continent': 'North America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2573, 'yr_of_estab': 1977, 'region_of_employment': 'Northeast', 'prevailing_wage': 91449.62, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 97: {'_id': ObjectId('697aec250bcaf783dbcf1ee5'), 'case_id': 'EZYV98', 'continent': 'North America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3524, 'yr_of_estab': 1982, 'region_of_employment': 'Midwest', 'prevailing_wage': 34494.86, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 98: {'_id': ObjectId('697aec250bcaf783dbcf1ee6'), 'case_id': 'EZYV99', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1847, 'yr_of_estab': 1977, 'region_of_employment': 'Northeast', 'prevailing_wage': 395.995, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 99: {'_id': ObjectId('697aec250bcaf783dbcf1ee7'), 'case_id': 'EZYV100', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 107535, 'yr_of_estab': 1970, 'region_of_employment': 'West', 'prevailing_wage': 159645.51, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 100: {'_id': ObjectId('697aec250bcaf783dbcf1ee8'), 'case_id': 'EZYV101', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2227, 'yr_of_estab': 2007, 'region_of_employment': 'Northeast', 'prevailing_wage': 28243.79, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# IOPub data rate exceeded.
# The Jupyter server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--ServerApp.iopub_data_rate_limit`.
#
# Current values:
# ServerApp.iopub_data_rate_limit=1000000.0 (bytes/sec)
# ServerApp.rate_limit_window=3.0 (secs)
# 25334: {'_id': ObjectId('697aec250bcaf783dbcf817a'), 'case_id': 'EZYV25335', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2089, 'yr_of_estab': 2014, 'region_of_employment': 'Northeast', 'prevailing_wage': 27729.43, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25335: {'_id': ObjectId('697aec250bcaf783dbcf817b'), 'case_id': 'EZYV25336', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 118, 'yr_of_estab': 1992, 'region_of_employment': 'Northeast', 'prevailing_wage': 80523.48, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25336: {'_id': ObjectId('697aec250bcaf783dbcf817c'), 'case_id': 'EZYV25337', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2043, 'yr_of_estab': 1968, 'region_of_employment': 'South', 'prevailing_wage': 75086.2, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25337: {'_id': ObjectId('697aec250bcaf783dbcf817d'), 'case_id': 'EZYV25338', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 909, 'yr_of_estab': 1999, 'region_of_employment': 'Midwest', 'prevailing_wage': 100743.2, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25338: {'_id': ObjectId('697aec250bcaf783dbcf817e'), 'case_id': 'EZYV25339', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1536, 'yr_of_estab': 2003, 'region_of_employment': 'South', 'prevailing_wage': 619.8479, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25339: {'_id': ObjectId('697aec250bcaf783dbcf817f'), 'case_id': 'EZYV25340', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1073, 'yr_of_estab': 2002, 'region_of_employment': 'West', 'prevailing_wage': 100824.65, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25340: {'_id': ObjectId('697aec250bcaf783dbcf8180'), 'case_id': 'EZYV25341', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2457, 'yr_of_estab': 1997, 'region_of_employment': 'Northeast', 'prevailing_wage': 56479.67, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25341: {'_id': ObjectId('697aec250bcaf783dbcf8181'), 'case_id': 'EZYV25342', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 688, 'yr_of_estab': 1984, 'region_of_employment': 'Midwest', 'prevailing_wage': 153694.13, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25342: {'_id': ObjectId('697aec250bcaf783dbcf8182'), 'case_id': 'EZYV25343', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 736, 'yr_of_estab': 2010, 'region_of_employment': 'South', 'prevailing_wage': 181607.5, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25343: {'_id': ObjectId('697aec250bcaf783dbcf8183'), 'case_id': 'EZYV25344', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 53376, 'yr_of_estab': 1875, 'region_of_employment': 'South', 'prevailing_wage': 58641.89, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25344: {'_id': ObjectId('697aec250bcaf783dbcf8184'), 'case_id': 'EZYV25345', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2989, 'yr_of_estab': 1988, 'region_of_employment': 'South', 'prevailing_wage': 136839.82, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25345: {'_id': ObjectId('697aec250bcaf783dbcf8185'), 'case_id': 'EZYV25346', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1923, 'yr_of_estab': 2001, 'region_of_employment': 'West', 'prevailing_wage': 101765.34, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25346: {'_id': ObjectId('697aec250bcaf783dbcf8186'), 'case_id': 'EZYV25347', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 3497, 'yr_of_estab': 1984, 'region_of_employment': 'Midwest', 'prevailing_wage': 671.1878, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25347: {'_id': ObjectId('697aec250bcaf783dbcf8187'), 'case_id': 'EZYV25348', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2203, 'yr_of_estab': 1999, 'region_of_employment': 'Midwest', 'prevailing_wage': 132574.3, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 25348: {'_id': ObjectId('697aec250bcaf783dbcf8188'), 'case_id': 'EZYV25349', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 36, 'yr_of_estab': 1993, 'region_of_employment': 'Midwest', 'prevailing_wage': 190311.67, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25349: {'_id': ObjectId('697aec250bcaf783dbcf8189'), 'case_id': 'EZYV25350', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 89016, 'yr_of_estab': 1965, 'region_of_employment': 'South', 'prevailing_wage': 223.0344, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25350: {'_id': ObjectId('697aec250bcaf783dbcf818a'), 'case_id': 'EZYV25351', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2426, 'yr_of_estab': 2007, 'region_of_employment': 'Midwest', 'prevailing_wage': 100051.66, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25351: {'_id': ObjectId('697aec250bcaf783dbcf818b'), 'case_id': 'EZYV25352', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2604, 'yr_of_estab': 1987, 'region_of_employment': 'South', 'prevailing_wage': 30952.8, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25352: {'_id': ObjectId('697aec250bcaf783dbcf818c'), 'case_id': 'EZYV25353', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 732, 'yr_of_estab': 2005, 'region_of_employment': 'Midwest', 'prevailing_wage': 98270.27, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25353: {'_id': ObjectId('697aec250bcaf783dbcf818d'), 'case_id': 'EZYV25354', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2414, 'yr_of_estab': 1887, 'region_of_employment': 'South', 'prevailing_wage': 43380.4, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25354: {'_id': ObjectId('697aec250bcaf783dbcf818e'), 'case_id': 'EZYV25355', 'continent': 'Europe', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 327, 'yr_of_estab': 1994, 'region_of_employment': 'South', 'prevailing_wage': 57577.91, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25355: {'_id': ObjectId('697aec250bcaf783dbcf818f'), 'case_id': 'EZYV25356', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 875, 'yr_of_estab': 1996, 'region_of_employment': 'Northeast', 'prevailing_wage': 49219.12, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25356: {'_id': ObjectId('697aec250bcaf783dbcf8190'), 'case_id': 'EZYV25357', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2181, 'yr_of_estab': 2004, 'region_of_employment': 'South', 'prevailing_wage': 63406.78, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25357: {'_id': ObjectId('697aec250bcaf783dbcf8191'), 'case_id': 'EZYV25358', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 6691, 'yr_of_estab': 2007, 'region_of_employment': 'West', 'prevailing_wage': 38097.67, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25358: {'_id': ObjectId('697aec250bcaf783dbcf8192'), 'case_id': 'EZYV25359', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 4423, 'yr_of_estab': 2004, 'region_of_employment': 'South', 'prevailing_wage': 126778.92, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# ...
# 25439: {'_id': ObjectId('697aec250bcaf783dbcf81e3'), 'case_id': 'EZYV25440', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 17337, 'yr_of_estab': 2006, 'region_of_employment': 'South', 'prevailing_wage': 34707.81, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25440: {'_id': ObjectId('697aec250bcaf783dbcf81e4'), 'case_id': 'EZYV25441', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 189, 'yr_of_estab': 1999, 'region_of_employment': 'South', 'prevailing_wage': 107049.53, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 25441: {'_id': ObjectId('697aec250bcaf783dbcf81e5'), 'case_id': 'EZYV25442', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 28199, 'yr_of_estab': 1988, 'region_of_employment': 'Northeast', 'prevailing_wage': 97906.76, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25442: {'_id': ObjectId('697aec250bcaf783dbcf81e6'), 'case_id': 'EZYV25443', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 4376, 'yr_of_estab': 1977, 'region_of_employment': 'West', 'prevailing_wage': 92363.32, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25443: {'_id': ObjectId('697aec250bcaf783dbcf81e7'), 'case_id': 'EZYV25444', 'continent': 'Africa', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 72892, 'yr_of_estab': 2007, 'region_of_employment': 'Northeast', 'prevailing_wage': 215.1, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25444: {'_id': ObjectId('697aec250bcaf783dbcf81e8'), 'case_id': 'EZYV25445', 'continent': 'South America', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1081, 'yr_of_estab': 1838, 'region_of_employment': 'Northeast', 'prevailing_wage': 156.607, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25445: {'_id': ObjectId('697aec250bcaf783dbcf81e9'), 'case_id': 'EZYV25446', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2642, 'yr_of_estab': 1890, 'region_of_employment': 'Northeast', 'prevailing_wage': 25899.99, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25446: {'_id': ObjectId('697aec250bcaf783dbcf81ea'), 'case_id': 'EZYV25447', 'continent': 'Africa', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 2024, 'yr_of_estab': 1971, 'region_of_employment': 'South', 'prevailing_wage': 42353.45, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25447: {'_id': ObjectId('697aec250bcaf783dbcf81eb'), 'case_id': 'EZYV25448', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4050, 'yr_of_estab': 1993, 'region_of_employment': 'Midwest', 'prevailing_wage': 117023.33, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25448: {'_id': ObjectId('697aec250bcaf783dbcf81ec'), 'case_id': 'EZYV25449', 'continent': 'Europe', 'education_of_employee': 'Doctorate', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4119, 'yr_of_estab': 1971, 'region_of_employment': 'West', 'prevailing_wage': 86894.1, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25449: {'_id': ObjectId('697aec250bcaf783dbcf81ed'), 'case_id': 'EZYV25450', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3017, 'yr_of_estab': 2000, 'region_of_employment': 'West', 'prevailing_wage': 39313.0, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25450: {'_id': ObjectId('697aec250bcaf783dbcf81ee'), 'case_id': 'EZYV25451', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 3312, 'yr_of_estab': 2009, 'region_of_employment': 'Northeast', 'prevailing_wage': 682.1048, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25451: {'_id': ObjectId('697aec250bcaf783dbcf81ef'), 'case_id': 'EZYV25452', 'continent': 'North America', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 97, 'yr_of_estab': 2013, 'region_of_employment': 'Northeast', 'prevailing_wage': 111518.59, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Denied'}
# 25452: {'_id': ObjectId('697aec250bcaf783dbcf81f0'), 'case_id': 'EZYV25453', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 70, 'yr_of_estab': 1995, 'region_of_employment': 'Northeast', 'prevailing_wage': 84833.89, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25453: {'_id': ObjectId('697aec250bcaf783dbcf81f1'), 'case_id': 'EZYV25454', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2804, 'yr_of_estab': 1937, 'region_of_employment': 'South', 'prevailing_wage': 33641.94, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25454: {'_id': ObjectId('697aec250bcaf783dbcf81f2'), 'case_id': 'EZYV25455', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1316, 'yr_of_estab': 2007, 'region_of_employment': 'South', 'prevailing_wage': 62844.97, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25455: {'_id': ObjectId('697aec250bcaf783dbcf81f3'), 'case_id': 'EZYV25456', 'continent': 'South America', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 24335, 'yr_of_estab': 1993, 'region_of_employment': 'Midwest', 'prevailing_wage': 97393.49, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25456: {'_id': ObjectId('697aec250bcaf783dbcf81f4'), 'case_id': 'EZYV25457', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 998, 'yr_of_estab': 1996, 'region_of_employment': 'South', 'prevailing_wage': 67340.65, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25457: {'_id': ObjectId('697aec250bcaf783dbcf81f5'), 'case_id': 'EZYV25458', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2257, 'yr_of_estab': 2004, 'region_of_employment': 'Midwest', 'prevailing_wage': 26397.07, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25458: {'_id': ObjectId('697aec250bcaf783dbcf81f6'), 'case_id': 'EZYV25459', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2591, 'yr_of_estab': 2002, 'region_of_employment': 'Island', 'prevailing_wage': 81497.19, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25459: {'_id': ObjectId('697aec250bcaf783dbcf81f7'), 'case_id': 'EZYV25460', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 4727, 'yr_of_estab': 1990, 'region_of_employment': 'Midwest', 'prevailing_wage': 53952.84, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25460: {'_id': ObjectId('697aec250bcaf783dbcf81f8'), 'case_id': 'EZYV25461', 'continent': 'Europe', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 413, 'yr_of_estab': 1997, 'region_of_employment': 'West', 'prevailing_wage': 8263.47, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25461: {'_id': ObjectId('697aec250bcaf783dbcf81f9'), 'case_id': 'EZYV25462', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2861, 'yr_of_estab': 2004, 'region_of_employment': 'West', 'prevailing_wage': 54.9196, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25462: {'_id': ObjectId('697aec250bcaf783dbcf81fa'), 'case_id': 'EZYV25463', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 1715, 'yr_of_estab': 2004, 'region_of_employment': 'West', 'prevailing_wage': 166032.62, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25463: {'_id': ObjectId('697aec250bcaf783dbcf81fb'), 'case_id': 'EZYV25464', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 444, 'yr_of_estab': 1838, 'region_of_employment': 'Midwest', 'prevailing_wage': 213189.36, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25464: {'_id': ObjectId('697aec250bcaf783dbcf81fc'), 'case_id': 'EZYV25465', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 48785, 'yr_of_estab': 1974, 'region_of_employment': 'South', 'prevailing_wage': 145102.36, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 25465: {'_id': ObjectId('697aec250bcaf783dbcf81fd'), 'case_id': 'EZYV25466', 'continent': 'North America', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2577, 'yr_of_estab': 1995, 'region_of_employment': 'South', 'prevailing_wage': 481.2238, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25466: {'_id': ObjectId('697aec250bcaf783dbcf81fe'), 'case_id': 'EZYV25467', 'continent': 'Europe', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1938, 'yr_of_estab': 2005, 'region_of_employment': 'West', 'prevailing_wage': 6973.4, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Denied'}
# 25467: {'_id': ObjectId('697aec250bcaf783dbcf81ff'), 'case_id': 'EZYV25468', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'N', 'requires_job_training': 'Y', 'no_of_employees': 2504, 'yr_of_estab': 1882, 'region_of_employment': 'Northeast', 'prevailing_wage': 105900.66, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25468: {'_id': ObjectId('697aec250bcaf783dbcf8200'), 'case_id': 'EZYV25469', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 373, 'yr_of_estab': 2005, 'region_of_employment': 'Midwest', 'prevailing_wage': 272715.74, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 25469: {'_id': ObjectId('697aec250bcaf783dbcf8201'), 'case_id': 'EZYV25470', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2261, 'yr_of_estab': 1997, 'region_of_employment': 'Northeast', 'prevailing_wage': 273772.47, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 25470: {'_id': ObjectId('697aec250bcaf783dbcf8202'), 'case_id': 'EZYV25471', 'continent': 'North America', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2272, 'yr_of_estab': 1970, 'region_of_employment': 'Northeast', 'prevailing_wage': 516.4101, 'unit_of_wage': 'Hour', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25471: {'_id': ObjectId('697aec250bcaf783dbcf8203'), 'case_id': 'EZYV25472', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 40224, 'yr_of_estab': 1962, 'region_of_employment': 'Island', 'prevailing_wage': 75587.42, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25472: {'_id': ObjectId('697aec250bcaf783dbcf8204'), 'case_id': 'EZYV25473', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 1346, 'yr_of_estab': 2003, 'region_of_employment': 'Midwest', 'prevailing_wage': 76155.6, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 25473: {'_id': ObjectId('697aec250bcaf783dbcf8205'), 'case_id': 'EZYV25474', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 2421, 'yr_of_estab': 2007, 'region_of_employment': 'Northeast', 'prevailing_wage': 22845.56, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25474: {'_id': ObjectId('697aec250bcaf783dbcf8206'), 'case_id': 'EZYV25475', 'continent': 'Africa', 'education_of_employee': 'Doctorate', 'has_job_experience': 'N', 'requires_job_training': 'N', 'no_of_employees': 2594, 'yr_of_estab': 1979, 'region_of_employment': 'Northeast', 'prevailing_wage': 51104.78, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25475: {'_id': ObjectId('697aec250bcaf783dbcf8207'), 'case_id': 'EZYV25476', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 2601, 'yr_of_estab': 2008, 'region_of_employment': 'South', 'prevailing_wage': 77092.57, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25476: {'_id': ObjectId('697aec250bcaf783dbcf8208'), 'case_id': 'EZYV25477', 'continent': 'Asia', 'education_of_employee': 'High School', 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3274, 'yr_of_estab': 2006, 'region_of_employment': 'Northeast', 'prevailing_wage': 279174.79, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25477: {'_id': ObjectId('697aec250bcaf783dbcf8209'), 'case_id': 'EZYV25478', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 1121, 'yr_of_estab': 1910, 'region_of_employment': 'South', 'prevailing_wage': 146298.85, 'unit_of_wage': 'Year', 'full_time_position': 'N', 'case_status': 'Certified'}
# 25478: {'_id': ObjectId('697aec250bcaf783dbcf820a'), 'case_id': 'EZYV25479', 'continent': 'Asia', 'education_of_employee': "Master's", 'has_job_experience': 'Y', 'requires_job_training': 'Y', 'no_of_employees': 1918, 'yr_of_estab': 1887, 'region_of_employment': 'West', 'prevailing_wage': 86154.77, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}
# 25479: {'_id': ObjectId('697aec250bcaf783dbcf820b'), 'case_id': 'EZYV25480', 'continent': 'Asia', 'education_of_employee': "Bachelor's", 'has_job_experience': 'Y', 'requires_job_training': 'N', 'no_of_employees': 3195, 'yr_of_estab': 1960, 'region_of_employment': 'Midwest', 'prevailing_wage': 70876.91, 'unit_of_wage': 'Year', 'full_time_position': 'Y', 'case_status': 'Certified'}

# %%
df = pd.DataFrame(list(collection.find()))
df.head()
# Out:
#                         _id case_id continent education_of_employee  \
# 0  697aec250bcaf783dbcf1e84  EZYV01      Asia           High School
# 1  697aec250bcaf783dbcf1e85  EZYV02      Asia              Master's
# 2  697aec250bcaf783dbcf1e86  EZYV03      Asia            Bachelor's
# 3  697aec250bcaf783dbcf1e87  EZYV04      Asia            Bachelor's
# 4  697aec250bcaf783dbcf1e88  EZYV05    Africa              Master's
#
#   has_job_experience requires_job_training  no_of_employees  yr_of_estab  \
# 0                  N                     N            14513         2007
# 1                  Y                     N             2412         2002
# 2                  N                     Y            44444         2008
# 3                  N                     N               98         1897
# 4                  Y                     N             1082         2005
#
#   region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 0                 West         592.2029         Hour                  Y
# 1            Northeast       83425.6500         Year                  Y
# 2                 West      122996.8600         Year                  Y
# 3                 West       83434.0300         Year                  Y
# 4                South      149907.3900         Year                  Y
#
#   case_status
# 0      Denied
# 1   Certified
# 2      Denied
# 3      Denied
# 4   Certified

# %%
if "_id" in df.columns.to_list():
    df = df.drop(columns=["_id"], axis=1)

# %%
df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# 1       83425.6500         Year                  Y   Certified
# 2      122996.8600         Year                  Y      Denied
# 3       83434.0300         Year                  Y      Denied
# 4      149907.3900         Year                  Y   Certified

# %%
# ## If you are getting timeout issue

# import certifi
# client = pymongo.MongoClient(CONNECTION_URL, tlsCAFile=certifi.where())
# # TO CREATE THE DATABASE
# data_base = client[DB_NAME]
# collection = data_base[COLLECTION_NAME]
# # TO INSERT DATA INTO THE COLLECTION
# rec = collection.insert_many(data)
